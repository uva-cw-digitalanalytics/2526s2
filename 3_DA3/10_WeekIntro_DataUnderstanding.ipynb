# %% [markdown]
# # Data cleaning
#
# By the end of the tutorials of this week, you should acquire:
#
# **Knowledge on:**
# * Inspection of dataframes
# * Identification and handling of missing values
# * Usage of functions to clean columns
# * Merging dataframes
# * Data minimization
# * Basic privacy preserving measures
#
# **Skills:**
# * .describe(), .dtypes
# * .isna().sum(), .fillna(), . dropna()
# * .apply() and selection of functions based on existing list
# * .merge()
# * .sample()

# %%
import pandas as pd

# %% [markdown]
# ## Loading data

# %% [markdown]
# Instead of using Twitter data for this tutorial, I decided to use data from YouTube. I collected it using the [YouTube Data Tools](https://tools.digitalmethods.net/netvizz/youtube/), also created by the Digital Methods Initiative from the UvA.
#
# The data I have is from a video search using the keyword "climate change".
#
# It always helps if we note down what we want to do with the data *before* we start. We can always refine these objectives later.
#
# ### What do I want to achieve with this analysis?
#
# Ideally I have a few research questions here. While we won't be able to do the visualisations (which we will learn on week 4) or statistical testing (week 5 and 6), I am noting down some research questions that may be interesting.
#
# * RQ1. To what extent does the sentiment expressed in the title of the video influence user engagement (views, likes and dislikes)?
# * RQ2. To what extent does the sentiment expressed in the title of the video vary depending on the category in which the video is published?
#
# **Important:** I only want to do this for videos published in 2021.
#
# These are examples - which are probably not very sophisticated yet as a business challenge - but they imply that we need a few things:
# 1. We need to have a sentiment analysis performed in the titles of the videos so we have the **sentiment** variable(s)
# 2. I need to make sure I have the user engagement variables (**likes**, **dislikes**, and **views**)
# 3. I need to have a variable for the **category** of the video
# 4. I need to know **when the video was published**, and remove old videos
#
# With this noted down, I can start loading, inspecting and cleaning the data.

# %%
videos = pd.read_csv('videolist_search500_2021_09_16-08_37_30.tab')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-2-5c6677308df6> in <module>
# ----> 1 videos = pd.read_csv('videolist_search500_2021_09_16-08_37_30.tab')
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 22 fields in line 3, saw 158

# %% [markdown]
# Because this is a tab-delimited file (i.e., the separators are tabs, not commas), I need to specify this in the read_csv command.

# %%
videos = pd.read_csv('videolist_search500_2021_09_16-08_37_30.tab', sep='\t')

# %%
len(videos)
# Out:
# 500

# %%
videos.head()
# Out:
#    position                 channelId                    channelTitle  \
# 0         1  UC18vz5hUUqxbGvym9ghtX_w  Full Frontal with Samantha Bee
# 1         2  UCJ6DCjlsOB8dwCrDbOLia6g                      Info Viral
# 2         3  UC18vz5hUUqxbGvym9ghtX_w  Full Frontal with Samantha Bee
# 3         4  UCEfvFsy9qbzeKyASsDs0V-w                        KJ Singh
# 4         5  UC7pluR6rB5KZIbN2IxamzxQ                BBC News Marathi
#
#        videoId           publishedAt       publishedAtSQL  \
# 0  xkgt1Avnvw0  2021-09-16T05:59:45Z  2021-09-16 05:59:45
# 1  Sf-klthGrqA  2021-09-16T06:00:06Z  2021-09-16 06:00:06
# 2  4Z0O1lJBU7g  2021-09-16T05:59:46Z  2021-09-16 05:59:46
# 3  KWoI9jTHHlk  2021-09-16T05:38:04Z  2021-09-16 05:38:04
# 4  32y2dG2tLOg  2021-09-16T04:58:32Z  2021-09-16 04:58:32
#
#                                           videoTitle  \
# 0  Vivian Howard: The Perfect Recipe for Combatin...
# 1  Global climate change!Cameroon under the snow,...
# 2  Food Waste and Climate Change: How Your Leftov...
# 3  Climate Change in Australia and Brexit #downun...
# 4  Climate Change : 50c सेल्शिअस तापमानाच्या ठिका...
#
#                                     videoDescription  \
# 0  Apocalyptic climate crisis got you down? Allow...
# 1  #GlobalClimateChange #CameroonUnderTheSnow #Sn...
# 2  The recent devastating climate report left man...
# 3                                                NaN
# 4  #ClimateChange #Temperature #Heat नायजेरिया दे...
#
#                                                 tags  videoCategoryId  ...  \
# 0  Full Frontal with Samantha Bee,Full Frontal,Sa...               24  ...
# 1  snow,snow fall,snow falling,snow fall in Camer...               26  ...
# 2  Full Frontal with Samantha Bee,Full Frontal,Sa...               24  ...
# 3                                                NaN               22  ...
# 4  Global Warming,Warming,Hottest place in world,...               25  ...
#
#   dimension definition  caption  \
# 0        2d         hd    False
# 1        2d         hd    False
# 2        2d         hd    False
# 3        2d         hd    False
# 4        2d         hd    False
#
#                                     thumbnail_maxres licensedContent  \
# 0  https://i.ytimg.com/vi/xkgt1Avnvw0/maxresdefau...             1.0
# 1                                                NaN             1.0
# 2  https://i.ytimg.com/vi/4Z0O1lJBU7g/maxresdefau...             1.0
# 3  https://i.ytimg.com/vi/KWoI9jTHHlk/maxresdefau...             NaN
# 4                                                NaN             1.0
#
#    viewCount likeCount  dislikeCount  favoriteCount  commentCount
# 0      796.0      88.0           2.0              0           9.0
# 1        2.0       0.0           0.0              0           0.0
# 2     1735.0     152.0           5.0              0          22.0
# 3        0.0       0.0           0.0              0           0.0
# 4     5442.0      81.0           3.0              0           5.0
#
# [5 rows x 23 columns]

# %%
videos.columns
# Out:
# Index(['position', 'channelId', 'channelTitle', 'videoId', 'publishedAt',
#        'publishedAtSQL', 'videoTitle', 'videoDescription', 'tags',
#        'videoCategoryId', 'videoCategoryLabel', 'duration', 'durationSec',
#        'dimension', 'definition', 'caption', 'thumbnail_maxres',
#        'licensedContent', 'viewCount', 'likeCount', 'dislikeCount',
#        'favoriteCount', 'commentCount'],
#       dtype='object')

# %%
videos.describe()
# Out:
#          position  videoCategoryId  durationSec  licensedContent  \
# count  500.000000       500.000000   500.000000            386.0
# mean   250.500000        24.896000   686.952000              1.0
# std    144.481833         3.237615   749.238875              0.0
# min      1.000000         1.000000    15.000000              1.0
# 25%    125.750000        25.000000   231.500000              1.0
# 50%    250.500000        25.000000   427.000000              1.0
# 75%    375.250000        27.000000   778.250000              1.0
# max    500.000000        30.000000  3585.000000              1.0
#
#           viewCount      likeCount  dislikeCount  favoriteCount  commentCount
# count  4.990000e+02     489.000000    489.000000          500.0    460.000000
# mean   3.573237e+05    9466.768916    881.370143            0.0   1588.645652
# std    1.253590e+06   40750.021842   5405.282802            0.0   5599.554476
# min    0.000000e+00       0.000000      0.000000            0.0      0.000000
# 25%    3.392500e+03      80.000000     10.000000            0.0     27.750000
# 50%    2.449100e+04     438.000000     58.000000            0.0    199.500000
# 75%    1.197805e+05    2969.000000    236.000000            0.0    787.500000
# max    1.534203e+07  478296.000000  91967.000000            0.0  68194.000000

# %%
videos.isna().sum()
# Out:
# position                0
# channelId               0
# channelTitle            0
# videoId                 0
# publishedAt             0
# publishedAtSQL          0
# videoTitle              0
# videoDescription       13
# tags                   55
# videoCategoryId         0
# videoCategoryLabel      0
# duration                0
# durationSec             0
# dimension               0
# definition              0
# caption                 0
# thumbnail_maxres      117
# licensedContent       114
# viewCount               1
# likeCount              11
# dislikeCount           11
# favoriteCount           0
# commentCount           40
# dtype: int64

# %% [markdown]
# *Some preliminary findings:*
# 1. It seems I have the variables measuring engagement I need, but likeCount and dislikeCount seem to have missing values
# 2. I need to run sentiment analysis on videoTitle, first I need to figure out what the language is of the titles (as this seems not to be provided by the API)
# 3. The videoCategoryLabel column seems to be a starting point for the category variable.
# 4. The publishedAt column can probably help me filter videos from 2021.
#
# All of this still needs to be confirmed though...

# %% [markdown]
# # Data cleaning

# %% [markdown]
# Now let's start preparing the data. The steps always depend on the dataset, but at a minimum we need to make sure that we:
# 1. Handle the missing values for relevant variables
# 2. Check if the variables are stored in the correct format/type
# 3. Create the variables we need (that may be not in the data yet)

# %% [markdown]
# ### Missing values

# %%
videos.isna().sum()
# Out:
# position                0
# channelId               0
# channelTitle            0
# videoId                 0
# publishedAt             0
# publishedAtSQL          0
# videoTitle              0
# videoDescription       13
# tags                   55
# videoCategoryId         0
# videoCategoryLabel      0
# duration                0
# durationSec             0
# dimension               0
# definition              0
# caption                 0
# thumbnail_maxres      117
# licensedContent       114
# viewCount               1
# likeCount              11
# dislikeCount           11
# favoriteCount           0
# commentCount           40
# dtype: int64

# %% [markdown]
# From the variables I am interested in, seems like likeCount, dislikeCount and viewCount are the ones that do have an issue. Let me check what's happening with them.
#
# One possibility would be that 0's are not included (i.e., if the video does not have a like, it will not appear). Let's see if that's the case...

# %%
videos[['likeCount', 'dislikeCount', 'viewCount']].describe()
# Out:
#            likeCount  dislikeCount     viewCount
# count     489.000000    489.000000  4.990000e+02
# mean     9466.768916    881.370143  3.573237e+05
# std     40750.021842   5405.282802  1.253590e+06
# min         0.000000      0.000000  0.000000e+00
# 25%        80.000000     10.000000  3.392500e+03
# 50%       438.000000     58.000000  2.449100e+04
# 75%      2969.000000    236.000000  1.197805e+05
# max    478296.000000  91967.000000  1.534203e+07

# %% [markdown]
# The minimum value is 0, so probably something else is going on. Let's see if this is related to channels (e.g., some channels not allowing users to like videos, perhaps?).

# %%
videos[videos['likeCount'].isna()]['channelTitle'].value_counts()
# Out:
# BBC News Hindi                                      5
# ExxonMobil                                          1
# Intergovernmental Panel on Climate Change (IPCC)    1
# Climate Change Committee                            1
# Act of Knowledge                                    1
# UNTV News and Rescue                                1
# YALI Network                                        1
# Name: channelTitle, dtype: int64

# %%
videos[videos['dislikeCount'].isna()]['channelTitle'].value_counts()
# Out:
# BBC News Hindi                                      5
# ExxonMobil                                          1
# Intergovernmental Panel on Climate Change (IPCC)    1
# Climate Change Committee                            1
# Act of Knowledge                                    1
# UNTV News and Rescue                                1
# YALI Network                                        1
# Name: channelTitle, dtype: int64

# %% [markdown]
# OK, so here's the list of channels that have missing likes and dislikes. They are in any case the same. Now let's see if they appear in a list of channels that have likes.

# %%
videos[videos['viewCount'].isna()]['channelTitle'].value_counts()
# Out:
# YouTube Movies    1
# Name: channelTitle, dtype: int64

# %% [markdown]
# And there is one channel that misses the number of views. It seems to be a movie.
#
# Let's check if the channels we have identified always have no likes or if they sometimes do.

# %% [markdown]
# First, let's make a list of all channels that do have likes and call it channels_with_likes.

# %%
channels_with_likes = videos[videos['likeCount'].isna()==False]['channelTitle'].unique().tolist()

# %%
channels_with_likes
# Out:
# ['Full Frontal with Samantha Bee',
#  'Info Viral',
#  'KJ Singh',
#  'BBC News Marathi',
#  'The Coalition Radio Network',
#  'Highest Truth',
#  'TruthRadioShow',
#  'KPBS',
#  'CBC News',
#  'Stuff',
#  'LACityClerk',
#  'UNTV News and Rescue',
#  'Derek Knight',
#  'CNBC Television',
#  'California DWR',
#  'US BREKING NEWS',
#  'CNBC',
#  'The News Forum',
#  'Pat Gray Unleashed',
#  'Make Peas Not Beef',
#  'Global Soil Biodiversity Initiative',
#  'Beril Sirmacek',
#  'KOIN 6',
#  'BBC News اردو',
#  'ksbscotland',
#  'PangeoHub',
#  'GoNewsIndia',
#  'FACE2FACE  C P JOHN  ',
#  'SubC Imaging',
#  'Sky News',
#  'KSAT 12',
#  'Ericsson',
#  'Big Beardy',
#  'Study IQ education',
#  'SBS News',
#  'BBC News',
#  'Greenish planet',
#  'SOMOY TV',
#  'TomoNews US',
#  'Scott Amyx',
#  'Tony Heller',
#  'Amazing Word Ministries',
#  'NewsNation Now',
#  'Associated Press',
#  'KARE 11',
#  'Denver7 – The Denver Channel',
#  'Eagle News',
#  'Allie Beth Stuckey',
#  'The Independent',
#  'Forbes Breaking News',
#  'Washington Post',
#  'Bloggingheads.tv',
#  'Sir Jimmy Savile',
#  'knowldge Factory',
#  'New York Post',
#  'draw with mridu',
#  'Jewish Learning Institute',
#  'The Vox',
#  'The Real Truth About Health',
#  'True North',
#  'Sagar Pade',
#  'BBC News Africa',
#  'Independent Television',
#  'Global Warming',
#  'Good Morning Britain',
#  'Shaw Spotlight',
#  'ABC News In-depth',
#  'Reuters',
#  'CBS Denver',
#  'KCRA News',
#  'ABC7 News Bay Area',
#  'WFAA',
#  'PBS NewsHour',
#  'Ad Council',
#  'CBS News',
#  'Knowland Knows',
#  'Sky News Australia',
#  'Dangerous Planet',
#  'Coach Red Pill',
#  'Climate change',
#  'RealJake',
#  'SciShow',
#  'Our Changing Climate',
#  'The Young Turks',
#  'CBS 17',
#  'Julie Nolke',
#  'The Late Show with Stephen Colbert',
#  'ESFTV',
#  'China Uncensored',
#  'MSNBC',
#  'ABC News',
#  'Getty Images',
#  'VICE News',
#  'NBC News',
#  'TODAY',
#  'CNN',
#  'Top Mindset',
#  'NowThis Earth',
#  'CBS Mornings',
#  'Global News',
#  'DW Planet A',
#  'Yahoo Finance',
#  'Simon & Schuster Books',
#  'National Post',
#  'Endless Thinker',
#  'Simon Clark',
#  'CNA Insider',
#  'TED',
#  'Just Have a Think',
#  'ENDEVR',
#  'The Deshbhakt',
#  'GMA News',
#  'The Hill',
#  'Forces News',
#  'Down To Earth',
#  'OTV',
#  'South China Morning Post',
#  'USA TODAY',
#  'MostAmazingTop10',
#  'Manorama News',
#  'Guardian News',
#  'channelocbc',
#  'ICCFoundation',
#  'Inside Edition',
#  'The School of Self',
#  'Sustainable Human',
#  'vlogbrothers',
#  'Breakfast Television',
#  'The Project',
#  'Zee News',
#  'Outpost News',
#  'CGTN',
#  'ABC News (Australia)',
#  'Al Jazeera English',
#  'Fox News',
#  'CBC News: The National',
#  'Moment News',
#  'Channel 4 News',
#  'The Sun',
#  'WION',
#  'Daily Mail',
#  'FRANCE 24 English',
#  'BBC',
#  'CBS Evening News',
#  'The Damage Report',
#  'Styxhexenhammer666',
#  'DW News',
#  'TOP Topics',
#  'Thom Hartmann Program',
#  'Channel 4 Comedy',
#  'Twisted Translations',
#  'The University of Buckingham',
#  'DW Documentary',
#  'Mashable',
#  'RT America',
#  "Young America's Foundation",
#  'Jack Harries',
#  'NHDES',
#  'Triggernometry',
#  'Sustainability Illustrated',
#  'Natural Calamities',
#  'Dhruv Rathee',
#  'Just Checkin in on yaaa',
#  'Emerson Brophy',
#  'Clear Energy Alliance',
#  'NEWS 1130',
#  'CGTN America',
#  'Arirang News',
#  'ABC Action News',
#  'ClimateAdam',
#  'John Stossel',
#  'Ellen MacArthur Foundation',
#  'ITBBerlin',
#  'The YEARS Project',
#  'Hanwha Group',
#  'Rep. Dan Crenshaw',
#  'TEDx Talks',
#  'RealLifeLore',
#  'Nakshatra Murthy',
#  'Deepto TV',
#  'Axios',
#  'Second Thought',
#  'CNBC International',
#  'CrashCourse',
#  'Conservation International',
#  'Independent Institute',
#  'The not so boring Man',
#  'The Daily Show with Trevor Noah',
#  'Neil Halloran',
#  '11Alive',
#  'Learn Bright',
#  'ScienceAtNASA',
#  'ClickView',
#  'Mobius Foundation',
#  'BritMonkey',
#  'Kurzgesagt – In a Nutshell',
#  'Cambridge University',
#  'Atlas Pro',
#  'Environment and Climate Change Canada',
#  'Hillsdale College',
#  "BYJU'S",
#  'workpointTODAY',
#  'Bill Gates',
#  '60 Minutes',
#  'Campus Reform',
#  'Veritasium',
#  'Financial Times',
#  'DJI Captures',
#  'euronews',
#  'The Economist',
#  'UpLevel Green',
#  'United Nations',
#  'Action for the Climate Emergency',
#  'BLACKPINK',
#  'Seeker',
#  'Climate Town',
#  'Jamaica Gleaner',
#  'news.com.au',
#  'Extinction Rebellion UK',
#  'YouTube Movies',
#  'AnthonyPadilla',
#  'Smile and Learn - English',
#  'CBS Sunday Morning',
#  'Holmen Iggesund',
#  'DW हिन्दी',
#  'Wind Energy Ireland',
#  'Good to Know',
#  'MrKravin',
#  'Nate Link MD',
#  'Pilan Records',
#  'Tuklas Kaalaman PH',
#  'Romain Pennes',
#  'LoverFella',
#  'เรียนรู้รักษ์ป่าน่าน',
#  'SoulPancake',
#  'Bloomberg Markets and Finance',
#  'Dave Malkoff',
#  'Hoover Institution',
#  'Big Think',
#  'Undecided with Matt Ferrell',
#  'Apple',
#  'UpIsNotJump',
#  'KINETIC SCHOOL',
#  'Universal Comedy',
#  'The Origins Podcast',
#  'mnr_geography',
#  'Los Angeles Times',
#  'Kurtis Baute',
#  'Long Now Foundation',
#  'Gawvi',
#  'HSGUniStGallen',
#  "It's Okay To Be Smart",
#  'WVTCH HD',
#  'BBC Newsnight',
#  'The Daily Wire',
#  'Alpha Paw',
#  'Verify Road Trip',
#  'European Commission',
#  'Dacru Records',
#  'Valuetainment',
#  'AsapSCIENCE',
#  'TL Documentary',
#  'Politically Aweh',
#  'Oversight Committee',
#  'Beau of the Fifth Column',
#  'talkRADIO',
#  'University of Oxford',
#  'BBC Ideas',
#  'edX',
#  'Wretched']

# %% [markdown]
# Using "in" operator we can check if an element is present in a list.

# %%
'BBC News Hindi' in channels_with_likes
# Out:
# False

# %%
'ExxonMobil' in channels_with_likes
# Out:
# False

# %% [markdown]
# This seems to be the case. But we cannot be very sure, so let's see how one of these video pages look like.

# %%
videos[videos['likeCount'].isna()]['videoId']
# Out:
# 112    _SWdCTTq6GY
# 133    hYoG5jg2rPA
# 186    Ksdo25JdiJY
# 217    z149vLKn9d8
# 247    NnnjIGiEhR4
# 249    0Zs6SfN08o0
# 301    qbzqRW80w68
# 317    Ornz7UHgn8w
# 417    oxbreqk8DIQ
# 471    syQCKbjZlyo
# 474    HqHuJngkJkE
# Name: videoId, dtype: object

# %% [markdown]
# Let me add the YouTube URL to some of these id's and see what's going on there:
#
# * https://www.youtube.com/watch?v=NnnjIGiEhR4
# * https://www.youtube.com/watch?v=hYoG5jg2rPA
# * https://www.youtube.com/watch?v=syQCKbjZlyo
# * https://www.youtube.com/watch?v=Ornz7UHgn8w
#
#
# It seems that for all of them the like and dislike counters are turned off. But it does not necessarily mean that the missing values are always a specific number (e.g., a zero).

# %%
videos[videos['viewCount'].isna()]['videoId']
# Out:
# 402    cU2HyoLfL38
# Name: videoId, dtype: object

# %% [markdown]
# Let me add the YouTube URL to some of these id's and see what's going on there:
#
# * https://www.youtube.com/watch?v=cU2HyoLfL38
#
# Indeed, this type of video does not have views count.

# %% [markdown]
# Ultimately, I have generally two options with missing values:
# * I can substitute them by another value (e.g., 0)
# * I can drop them from the dataset

# %% [markdown]
# If I wanted to substitute them by another value, I would use the following command:

# %%
videos['dislikeCount_no_na'] = videos['dislikeCount'].fillna(0)

# %%
videos.isna().sum()
# Out:
# position                0
# channelId               0
# channelTitle            0
# videoId                 0
# publishedAt             0
# publishedAtSQL          0
# videoTitle              0
# videoDescription       13
# tags                   55
# videoCategoryId         0
# videoCategoryLabel      0
# duration                0
# durationSec             0
# dimension               0
# definition              0
# caption                 0
# thumbnail_maxres      117
# licensedContent       114
# viewCount               1
# likeCount              11
# dislikeCount           11
# favoriteCount           0
# commentCount           40
# dislikeCount_no_na      0
# dtype: int64

# %% [markdown]
# But it doesn't seem to be appropriate here, as the number of likes, dislikes and views for the identified videos is not being informed - we cannot see these values on YouTube either. So it is a limitation (that we need to acknowledge in our reporting), but most likely dropping these values is better.
#
# To do so, I can run the following command:

# %%
videos = videos.dropna(subset=['likeCount', 'dislikeCount', 'viewCount'])

# %%
videos.isna().sum()
# Out:
# position                0
# channelId               0
# channelTitle            0
# videoId                 0
# publishedAt             0
# publishedAtSQL          0
# videoTitle              0
# videoDescription       13
# tags                   51
# videoCategoryId         0
# videoCategoryLabel      0
# duration                0
# durationSec             0
# dimension               0
# definition              0
# caption                 0
# thumbnail_maxres      111
# licensedContent       109
# viewCount               0
# likeCount               0
# dislikeCount            0
# favoriteCount           0
# commentCount           35
# dislikeCount_no_na      0
# dtype: int64

# %%
len(videos)
# Out:
# 488

# %% [markdown]
# ### Checking the data types
#
# It is also important to check if we have the data stored in the right format. Let's inspect it:

# %%
videos.dtypes
# Out:
# position                int64
# channelId              object
# channelTitle           object
# videoId                object
# publishedAt            object
# publishedAtSQL         object
# videoTitle             object
# videoDescription       object
# tags                   object
# videoCategoryId         int64
# videoCategoryLabel     object
# duration               object
# durationSec             int64
# dimension              object
# definition             object
# caption                  bool
# thumbnail_maxres       object
# licensedContent       float64
# viewCount             float64
# likeCount             float64
# dislikeCount          float64
# favoriteCount           int64
# commentCount          float64
# dislikeCount_no_na    float64
# dtype: object

# %% [markdown]
# From my key variables so far (likeCount, dislikeCount, viewCount, videoTitle, videoCategoryLabel), all looks OK. The numeric variables are in numeric form (int or float), and the text variables are in object form.
#
# But the date variable (publishedAt) is stored as an object... and it should be a date.

# %%
videos['publishedAt'].head()
# Out:
# 0    2021-09-16T05:59:45Z
# 1    2021-09-16T06:00:06Z
# 2    2021-09-16T05:59:46Z
# 3    2021-09-16T05:38:04Z
# 4    2021-09-16T04:58:32Z
# Name: publishedAt, dtype: object

# %% [markdown]
# Yes, it looks like a date, but it is stored as an object. This is a problem, because I cannot filter the dataset by date.

# %%
videos['publishedAt'] = videos['publishedAt'].apply(pd.to_datetime)

# %%
videos['publishedAt'].head()
# Out:
# 0   2021-09-16 05:59:45+00:00
# 1   2021-09-16 06:00:06+00:00
# 2   2021-09-16 05:59:46+00:00
# 3   2021-09-16 05:38:04+00:00
# 4   2021-09-16 04:58:32+00:00
# Name: publishedAt, dtype: datetime64[ns, UTC]

# %%
videos.dtypes
# Out:
# position                            int64
# channelId                          object
# channelTitle                       object
# videoId                            object
# publishedAt           datetime64[ns, UTC]
# publishedAtSQL                     object
# videoTitle                         object
# videoDescription                   object
# tags                               object
# videoCategoryId                     int64
# videoCategoryLabel                 object
# duration                           object
# durationSec                         int64
# dimension                          object
# definition                         object
# caption                              bool
# thumbnail_maxres                   object
# licensedContent                   float64
# viewCount                         float64
# likeCount                         float64
# dislikeCount                      float64
# favoriteCount                       int64
# commentCount                      float64
# dislikeCount_no_na                float64
# dtype: object

# %% [markdown]
# Now we can for example check the videos published in 2019 and 2020, for example:

# %%
videos[videos['publishedAt'] >'2021-01-01']
# Out:
#      position                 channelId                    channelTitle  \
# 0           1  UC18vz5hUUqxbGvym9ghtX_w  Full Frontal with Samantha Bee
# 1           2  UCJ6DCjlsOB8dwCrDbOLia6g                      Info Viral
# 2           3  UC18vz5hUUqxbGvym9ghtX_w  Full Frontal with Samantha Bee
# 3           4  UCEfvFsy9qbzeKyASsDs0V-w                        KJ Singh
# 4           5  UC7pluR6rB5KZIbN2IxamzxQ                BBC News Marathi
# ..        ...                       ...                             ...
# 376       377  UCZYTClx2T1of7BRZ86-8fow                         SciShow
# 377       378  UCSrZ3UV4jOidv8ppoVuvW9Q                        euronews
# 378       379  UC0p5jTq6Xx_DosDFxVXnWaQ                   The Economist
# 379       380  UCMF296pHoCPUC_IxpYoG1Cg                   UpLevel Green
# 380       381  UCc5vZEM1MLUzCrg_aZIJdeA            Cambridge University
#
#          videoId               publishedAt       publishedAtSQL  \
# 0    xkgt1Avnvw0 2021-09-16 05:59:45+00:00  2021-09-16 05:59:45
# 1    Sf-klthGrqA 2021-09-16 06:00:06+00:00  2021-09-16 06:00:06
# 2    4Z0O1lJBU7g 2021-09-16 05:59:46+00:00  2021-09-16 05:59:46
# 3    KWoI9jTHHlk 2021-09-16 05:38:04+00:00  2021-09-16 05:38:04
# 4    32y2dG2tLOg 2021-09-16 04:58:32+00:00  2021-09-16 04:58:32
# ..           ...                       ...                  ...
# 376  1NBQZkySDY0 2021-01-22 22:53:49+00:00  2021-01-22 22:53:49
# 377  w3VUI3K2n5o 2021-01-21 18:08:31+00:00  2021-01-21 18:08:31
# 378  7vOwjNTDwBE 2021-01-13 15:11:16+00:00  2021-01-13 15:11:16
# 379  ZwyEW_rDeqQ 2021-01-05 18:33:50+00:00  2021-01-05 18:33:50
# 380  G9AxUZwENfc 2021-01-05 09:27:29+00:00  2021-01-05 09:27:29
#
#                                             videoTitle  \
# 0    Vivian Howard: The Perfect Recipe for Combatin...
# 1    Global climate change!Cameroon under the snow,...
# 2    Food Waste and Climate Change: How Your Leftov...
# 3    Climate Change in Australia and Brexit #downun...
# 4    Climate Change : 50c सेल्शिअस तापमानाच्या ठिका...
# ..                                                 ...
# 376  Oh No...Is Nature Going to Make Climate Change...
# 377  Did the coronavirus pandemic alter the course ...
# 378  How can business survive climate change? | The...
# 379  Jordan Peterson on Climate Change: "8 Rules fo...
# 380  Podcast: Is climate change actually being take...
#
#                                       videoDescription  \
# 0    Apocalyptic climate crisis got you down? Allow...
# 1    #GlobalClimateChange #CameroonUnderTheSnow #Sn...
# 2    The recent devastating climate report left man...
# 3                                                  NaN
# 4    #ClimateChange #Temperature #Heat नायजेरिया दे...
# ..                                                 ...
# 376  Photosynthesis plays a huge role in regulating...
# 377  2020 was a record-breaking year for the health...
# 378  Climate change is about to upend the corporate...
# 379  Jordan Peterson has some controversial thought...
# 380  In this last episode of the series, we’ll be e...
#
#                                                   tags  videoCategoryId  ...  \
# 0    Full Frontal with Samantha Bee,Full Frontal,Sa...               24  ...
# 1    snow,snow fall,snow falling,snow fall in Camer...               26  ...
# 2    Full Frontal with Samantha Bee,Full Frontal,Sa...               24  ...
# 3                                                  NaN               22  ...
# 4    Global Warming,Warming,Hottest place in world,...               25  ...
# ..                                                 ...              ...  ...
# 376  SciShow,science,Hank,Green,education,learn,cli...               27  ...
# 377  climate,climate change,global warming,climate ...               25  ...
# 378  The Economist,Economist,Economist Films,Econom...               25  ...
# 379  jordan peterson,climate change,greta thunberg,...               28  ...
# 380                     Cambridge,Cambridge University               27  ...
#
#     definition caption                                   thumbnail_maxres  \
# 0           hd   False  https://i.ytimg.com/vi/xkgt1Avnvw0/maxresdefau...
# 1           hd   False                                                NaN
# 2           hd   False  https://i.ytimg.com/vi/4Z0O1lJBU7g/maxresdefau...
# 3           hd   False  https://i.ytimg.com/vi/KWoI9jTHHlk/maxresdefau...
# 4           hd   False                                                NaN
# ..         ...     ...                                                ...
# 376         hd    True  https://i.ytimg.com/vi/1NBQZkySDY0/maxresdefau...
# 377         hd   False  https://i.ytimg.com/vi/w3VUI3K2n5o/maxresdefau...
# 378         hd    True  https://i.ytimg.com/vi/7vOwjNTDwBE/maxresdefau...
# 379         hd   False  https://i.ytimg.com/vi/ZwyEW_rDeqQ/maxresdefau...
# 380         hd   False  https://i.ytimg.com/vi/G9AxUZwENfc/maxresdefau...
#
#     licensedContent viewCount  likeCount dislikeCount  favoriteCount  \
# 0               1.0     796.0       88.0          2.0              0
# 1               1.0       2.0        0.0          0.0              0
# 2               1.0    1735.0      152.0          5.0              0
# 3               NaN       0.0        0.0          0.0              0
# 4               1.0    5442.0       81.0          3.0              0
# ..              ...       ...        ...          ...            ...
# 376             1.0  164492.0    10263.0        272.0              0
# 377             1.0   63681.0      102.0         35.0              0
# 378             1.0  246492.0     4445.0        191.0              0
# 379             NaN    1602.0       30.0          4.0              0
# 380             NaN    3349.0       86.0          2.0              0
#
#      commentCount  dislikeCount_no_na
# 0             9.0                 2.0
# 1             0.0                 0.0
# 2            22.0                 5.0
# 3             0.0                 0.0
# 4             5.0                 3.0
# ..            ...                 ...
# 376        1368.0               272.0
# 377          27.0                35.0
# 378         518.0               191.0
# 379          12.0                 4.0
# 380          11.0                 2.0
#
# [373 rows x 24 columns]

# %% [markdown]
# Or I can get the oldest and the latest date for the videos:

# %%
videos['publishedAt'].min()
# Out:
# Timestamp('2019-08-27 16:13:16+0000', tz='UTC')

# %%
videos['publishedAt'].max()
# Out:
# Timestamp('2021-09-16 06:00:06+0000', tz='UTC')

# %%
len(videos)
# Out:
# 488

# %%
len(videos[videos['publishedAt'] >'2021-01-01'])
# Out:
# 373

# %%
videos = videos[videos['publishedAt'] >'2021-01-01']

# %% [markdown]
# ### Important!
#
# Above we have used the ```.apply``` method to run a function in that column. Curious about other things you can do with it? Check out the notebook "UsefulFunctions" in the "UsefulScripts" folder.

# %% [markdown]
# OK, just to recap, this is the status of the variables that we need:
# * Engagement: likeCount and dislikeCount are in the right type (int or float) and we fixed the missing values
# * Sentiment: the videoTitle column is in the right type (object), but we don't have sentiment yet
# * Category: we have the videoCategoryLabel, but we're not sure if it is really that informative yet
# * PublishedAt: we corrected the data type, and managed to slice the dataframe correctly. Yes!

# %% [markdown]
# ## Requesting sentiment analysis
#
# As I don't have the language of the videos, I am going to use a Python module to automatically detect the language. It's available in the ```UsefulScripts``` folder, in the ```AdvancedModules``` notebook. If you want to use it, make sure to read the details in that notebook, as you may need to install a few things!

# %%
from langdetect import detect

# %%
def apply_langdetect(text):
    text = str(text)
    try:
        lang = detect(text)
    except:
        lang = 'error'
        
    return lang

# %%
videos['lang_title'] = videos['videoTitle'].apply(apply_langdetect)

# %%
videos['lang_title'].value_counts()
# Out:
# en    356
# bn      7
# ml      3
# ro      2
# mr      1
# de      1
# tl      1
# fr      1
# th      1
# Name: lang_title, dtype: int64

# %%
videos[videos['lang_title']!='en'][['lang_title', 'videoTitle']]
# Out:
#     lang_title                                         videoTitle
# 4           mr  Climate Change : 50c सेल्शिअस तापमानाच्या ठिका...
# 19          de  BREAKING NEWS! BIDEN ADMITS SPEND $7 BILLION O...
# 31          ml  C P JOHN I ഇരുപത്തിആറാമത് കാലാവസ്ഥാ വ്യതിയാന സ...
# 41          bn  ৩০ বছরে দেশের প্রায় দেড় কোটি মানুষ অভিবাসী হবে...
# 63          ml  പ്രളയം വരുന്നു ഗ്രീന്‍ലന്‍ഡില്‍ നിന്ന് / Green...
# 66          bn  চরম ভয়াবহতার সাক্ষী হতে যাচ্ছে পৃথিবী | Climat...
# 69          bn  'বাংলাদেশের ১৭ শতাংশ এলাকা পানিতে তলিয়ে যাবে'।...
# 72          bn  জলবায়ু পরিবর্তনের কারণে বিশ্বে গরম দিনের সংখ্য...
# 117         bn  পৃথিবীর ধ্বংস জলবায়ু পরিবর্তনেই | Climate Chan...
# 121         bn  তাহলে কি পৃথিবীর শেষ দিন ঘনিয়ে আসছে? | Climate...
# 153         tl  Bakit dapat tayong mabahala sa bagong climate ...
# 166         ml  കൊച്ചി അടക്കം പ്രധാന നഗരങ്ങളെ കടലെടുക്കും; നാസ...
# 227         bn  জলবায়ু পরিবর্তন যদি হাঙর হয়, পানি হাঙরের দাঁত!...
# 252         ro                         Time’s Up: Climate CHANGED
# 268         fr           EU unveils ambitious climate change plan
# 368         ro         Climate change in Romania | DW Documentary
# 369         th  บิล เกตส์ ชี้ ปัญหา Climate Change ท้าทายยิ่งก...

# %% [markdown]
# The language detection module doesn't seem to be working all the time. But it did identify a video with a Russian title. So we can safely remove that video, and make a judgement call of what to do with the rest.

# %%
videos = videos[(videos['lang_title']!= 'bn') & (videos['lang_title']!= 'ml') & (videos['lang_title']!= 'tl') & (videos['lang_title']!= 'th')]

# %%
len(videos)
# Out:
# 361

# %% [markdown]
# Now I can export it for sentiment analysis. When doing so, I will also need to change the column name - from videoTitle to text -, otherwise the sentiment analysis script won't know what to do.

# %%
sent_export = videos[['videoId', 'videoTitle']].rename(columns={'videoTitle': 'text'})

# %%
sent_export.head()
# Out:
#        videoId                                               text
# 0  xkgt1Avnvw0  Vivian Howard: The Perfect Recipe for Combatin...
# 1  Sf-klthGrqA  Global climate change!Cameroon under the snow,...
# 2  4Z0O1lJBU7g  Food Waste and Climate Change: How Your Leftov...
# 3  KWoI9jTHHlk  Climate Change in Australia and Brexit #downun...
# 4  32y2dG2tLOg  Climate Change : 50c सेल्शिअस तापमानाच्या ठिका...

# %%
sent_export.to_pickle('Sentiment/JoannaStrycharz_YouTubeClimateChange_EN.pkl')

# %% [markdown]
# Now I would usually upload this file to OneDrive (see links in the homepage of the General Repository) and have to wait one or two workdays until the analysis is complete.
#
# When it is complete, I will find the file in the ```SentimentAnalysisResults``` folder also on OneDrive. I have to download it and add to the same folder I am working on now.

# %%
sentiment = pd.read_pickle('Sentiment/JoannaStrycharz_YouTubeClimateChange_EN_completed.pkl')

# %%
sentiment.head()
# Out:
#        videoId negative positive neutral
# 0  xkgt1Avnvw0       -1        1       0
# 1  Sf-klthGrqA       -1        2       1
# 2  4Z0O1lJBU7g       -1        1       0
# 3  KWoI9jTHHlk       -1        1       0
# 4  32y2dG2tLOg       -1        1       0

# %%
sentiment.dtypes
# Out:
# videoId     object
# negative    object
# positive    object
# neutral     object
# dtype: object

# %%
sentiment.isna().sum()
# Out:
# videoId     0
# negative    0
# positive    0
# neutral     0
# dtype: int64

# %% [markdown]
# ### Important tip!
#
# It seems I need to clean this variable (sentiment seems to be stored as an object). I will not show this in the video as this is part of the weekly challenge :-)
#
# *But I still need to merge the dataframes...*

# %% [markdown]
# ## Merging the dataframes
#
# Merging dataframes is an operation to bring the data of one dataframe into the other (or rather create a new dataframe). This is covered extensively in a video in the ```FAQs``` folder, and we will review it in class in a bit more detail (in DA3 and DA4).
#
# Basically, we need to use the command ```.merge```. A few important tips:
# * Make sure that you have one unique identifier (column) that is available in both dataframes
# * Make sure that the unique identifier column has the same name in both dataframes
# * Make sure that the unique identifier column is of the same data type in both dataframes

# %% [markdown]
# In our case, the unique identifier is videoId. Let's check the items above step by step:

# %%
videos.columns
# Out:
# Index(['position', 'channelId', 'channelTitle', 'videoId', 'publishedAt',
#        'publishedAtSQL', 'videoTitle', 'videoDescription', 'tags',
#        'videoCategoryId', 'videoCategoryLabel', 'duration', 'durationSec',
#        'dimension', 'definition', 'caption', 'thumbnail_maxres',
#        'licensedContent', 'viewCount', 'likeCount', 'dislikeCount',
#        'favoriteCount', 'commentCount', 'dislikeCount_no_na', 'lang_title'],
#       dtype='object')

# %%
sentiment.columns
# Out:
# Index(['videoId', 'negative', 'positive', 'neutral'], dtype='object')

# %%
videos.dtypes
# Out:
# position                            int64
# channelId                          object
# channelTitle                       object
# videoId                            object
# publishedAt           datetime64[ns, UTC]
# publishedAtSQL                     object
# videoTitle                         object
# videoDescription                   object
# tags                               object
# videoCategoryId                     int64
# videoCategoryLabel                 object
# duration                           object
# durationSec                         int64
# dimension                          object
# definition                         object
# caption                              bool
# thumbnail_maxres                   object
# licensedContent                   float64
# viewCount                         float64
# likeCount                         float64
# dislikeCount                      float64
# favoriteCount                       int64
# commentCount                      float64
# dislikeCount_no_na                float64
# lang_title                         object
# dtype: object

# %%
sentiment.dtypes
# Out:
# videoId     object
# negative    object
# positive    object
# neutral     object
# dtype: object

# %% [markdown]
# OK, the column is available in both, and seems to be of the same data type. So I can merge.

# %%
len(videos)
# Out:
# 361

# %%
len(sentiment)
# Out:
# 360

# %%
videos.merge(sentiment, on='videoId')
# Out:
#      position                 channelId                    channelTitle  \
# 0           1  UC18vz5hUUqxbGvym9ghtX_w  Full Frontal with Samantha Bee
# 1           2  UCJ6DCjlsOB8dwCrDbOLia6g                      Info Viral
# 2           3  UC18vz5hUUqxbGvym9ghtX_w  Full Frontal with Samantha Bee
# 3           4  UCEfvFsy9qbzeKyASsDs0V-w                        KJ Singh
# 4           5  UC7pluR6rB5KZIbN2IxamzxQ                BBC News Marathi
# ..        ...                       ...                             ...
# 363       377  UCZYTClx2T1of7BRZ86-8fow                         SciShow
# 364       378  UCSrZ3UV4jOidv8ppoVuvW9Q                        euronews
# 365       379  UC0p5jTq6Xx_DosDFxVXnWaQ                   The Economist
# 366       380  UCMF296pHoCPUC_IxpYoG1Cg                   UpLevel Green
# 367       381  UCc5vZEM1MLUzCrg_aZIJdeA            Cambridge University
#
#          videoId               publishedAt       publishedAtSQL  \
# 0    xkgt1Avnvw0 2021-09-16 05:59:45+00:00  2021-09-16 05:59:45
# 1    Sf-klthGrqA 2021-09-16 06:00:06+00:00  2021-09-16 06:00:06
# 2    4Z0O1lJBU7g 2021-09-16 05:59:46+00:00  2021-09-16 05:59:46
# 3    KWoI9jTHHlk 2021-09-16 05:38:04+00:00  2021-09-16 05:38:04
# 4    32y2dG2tLOg 2021-09-16 04:58:32+00:00  2021-09-16 04:58:32
# ..           ...                       ...                  ...
# 363  1NBQZkySDY0 2021-01-22 22:53:49+00:00  2021-01-22 22:53:49
# 364  w3VUI3K2n5o 2021-01-21 18:08:31+00:00  2021-01-21 18:08:31
# 365  7vOwjNTDwBE 2021-01-13 15:11:16+00:00  2021-01-13 15:11:16
# 366  ZwyEW_rDeqQ 2021-01-05 18:33:50+00:00  2021-01-05 18:33:50
# 367  G9AxUZwENfc 2021-01-05 09:27:29+00:00  2021-01-05 09:27:29
#
#                                             videoTitle  \
# 0    Vivian Howard: The Perfect Recipe for Combatin...
# 1    Global climate change!Cameroon under the snow,...
# 2    Food Waste and Climate Change: How Your Leftov...
# 3    Climate Change in Australia and Brexit #downun...
# 4    Climate Change : 50c सेल्शिअस तापमानाच्या ठिका...
# ..                                                 ...
# 363  Oh No...Is Nature Going to Make Climate Change...
# 364  Did the coronavirus pandemic alter the course ...
# 365  How can business survive climate change? | The...
# 366  Jordan Peterson on Climate Change: "8 Rules fo...
# 367  Podcast: Is climate change actually being take...
#
#                                       videoDescription  \
# 0    Apocalyptic climate crisis got you down? Allow...
# 1    #GlobalClimateChange #CameroonUnderTheSnow #Sn...
# 2    The recent devastating climate report left man...
# 3                                                  NaN
# 4    #ClimateChange #Temperature #Heat नायजेरिया दे...
# ..                                                 ...
# 363  Photosynthesis plays a huge role in regulating...
# 364  2020 was a record-breaking year for the health...
# 365  Climate change is about to upend the corporate...
# 366  Jordan Peterson has some controversial thought...
# 367  In this last episode of the series, we’ll be e...
#
#                                                   tags  videoCategoryId  ...  \
# 0    Full Frontal with Samantha Bee,Full Frontal,Sa...               24  ...
# 1    snow,snow fall,snow falling,snow fall in Camer...               26  ...
# 2    Full Frontal with Samantha Bee,Full Frontal,Sa...               24  ...
# 3                                                  NaN               22  ...
# 4    Global Warming,Warming,Hottest place in world,...               25  ...
# ..                                                 ...              ...  ...
# 363  SciShow,science,Hank,Green,education,learn,cli...               27  ...
# 364  climate,climate change,global warming,climate ...               25  ...
# 365  The Economist,Economist,Economist Films,Econom...               25  ...
# 366  jordan peterson,climate change,greta thunberg,...               28  ...
# 367                     Cambridge,Cambridge University               27  ...
#
#     viewCount likeCount  dislikeCount favoriteCount commentCount  \
# 0       796.0      88.0           2.0             0          9.0
# 1         2.0       0.0           0.0             0          0.0
# 2      1735.0     152.0           5.0             0         22.0
# 3         0.0       0.0           0.0             0          0.0
# 4      5442.0      81.0           3.0             0          5.0
# ..        ...       ...           ...           ...          ...
# 363  164492.0   10263.0         272.0             0       1368.0
# 364   63681.0     102.0          35.0             0         27.0
# 365  246492.0    4445.0         191.0             0        518.0
# 366    1602.0      30.0           4.0             0         12.0
# 367    3349.0      86.0           2.0             0         11.0
#
#      dislikeCount_no_na lang_title  negative  positive  neutral
# 0                   2.0         en        -1         1        0
# 1                   0.0         en        -1         2        1
# 2                   5.0         en        -1         1        0
# 3                   0.0         en        -1         1        0
# 4                   3.0         mr        -1         1        0
# ..                  ...        ...       ...       ...      ...
# 363               272.0         en        -4         1       -1
# 364                35.0         en        -1         1        0
# 365               191.0         en        -1         1        0
# 366                 4.0         en        -1         1        0
# 367                 2.0         en        -1         1        0
#
# [368 rows x 28 columns]

# %%
len(videos.merge(sentiment, on='videoId'))
# Out:
# 368

# %% [markdown]
# Let's explore different types of merges a bit further.

# %%
len(videos.merge(sentiment, on='videoId', how='left'))
# Out:
# 369

# %%
len(videos.merge(sentiment, on='videoId', how='right'))
# Out:
# 368

# %%
len(videos.merge(sentiment, on='videoId', how='inner'))
# Out:
# 368

# %%
len(videos.merge(sentiment, on='videoId', how='outer'))
# Out:
# 369

# %%
videos_sent = videos.merge(sentiment, on='videoId')

# %% [markdown]
# We are almost there. Let's recap where we are:
# * Engagement (OK): likeCount, dislikeCount and viewCount are in the right type (int or float) and we fixed the missing values
# * Sentiment (OK-ish): we have the sentiment analysis results for the title, but they are in the wrong dtype. We won't fix it now - as you need to do it for the weekly challenge ;)
# * Category: we have the videoCategoryLabel, but we're not sure if it is really that informative yet
# * PublishedAt (OK): we corrected the data type, and managed to slice the dataframe correctly. Yes!
#
# So we just need to work on the Category now.

# %% [markdown]
# ## Video Categories

# %%
videos_sent['videoCategoryLabel'].value_counts()
# Out:
# News & Politics          220
# Education                 44
# People & Blogs            29
# Entertainment             26
# Science & Technology      21
# Nonprofits & Activism     15
# Comedy                     5
# Travel & Events            3
# Film & Animation           3
# Howto & Style              1
# Music                      1
# Name: videoCategoryLabel, dtype: int64

# %% [markdown]
# We have waaaay too many categories here to make informative comparisons, and some of them are very small (1 video), while others have a lot of videos. While we that will almost always be the case for digital trace data, we can at least recategorize this a bit...

# %%
def recategorize(category):
    if category == 'News & Politics':
        return category
    if category == 'Education':
        return 'Education, Science and Technology'
    if category == 'Science & Technology':
        return 'Education, Science and Technology'
    if category == 'Nonprofits & Activism':
        return category
    else:
        return 'Other'

# %%
videos_sent['category'] = videos_sent['videoCategoryLabel'].apply(recategorize)

# %%
videos_sent['category'].value_counts()
# Out:
# News & Politics                      220
# Other                                 68
# Education, Science and Technology     65
# Nonprofits & Activism                 15
# Name: category, dtype: int64

# %% [markdown]
# This recategorization is not ideal, but at least we have four large(r) categories. One could argue that nonprofits is still too small. But for now we'll keep as is.

# %%
videos_sent.columns
# Out:
# Index(['position', 'channelId', 'channelTitle', 'videoId', 'publishedAt',
#        'publishedAtSQL', 'videoTitle', 'videoDescription', 'tags',
#        'videoCategoryId', 'videoCategoryLabel', 'duration', 'durationSec',
#        'dimension', 'definition', 'caption', 'thumbnail_maxres',
#        'licensedContent', 'viewCount', 'likeCount', 'dislikeCount',
#        'favoriteCount', 'commentCount', 'dislikeCount_no_na', 'lang_title',
#        'negative', 'positive', 'neutral', 'category'],
#       dtype='object')

# %%
videos_sent.isna().sum()
# Out:
# position               0
# channelId              0
# channelTitle           0
# videoId                0
# publishedAt            0
# publishedAtSQL         0
# videoTitle             0
# videoDescription      12
# tags                  41
# videoCategoryId        0
# videoCategoryLabel     0
# duration               0
# durationSec            0
# dimension              0
# definition             0
# caption                0
# thumbnail_maxres      89
# licensedContent       78
# viewCount              0
# likeCount              0
# dislikeCount           0
# favoriteCount          0
# commentCount          30
# dislikeCount_no_na     0
# lang_title             0
# negative               0
# positive               0
# neutral                0
# category               0
# dtype: int64

# %%
videos_sent.describe()
# Out:
#          position  videoCategoryId  durationSec  licensedContent  \
# count  368.000000       368.000000   368.000000            290.0
# mean   196.095109        24.956522   638.904891              1.0
# std    111.952326         2.846339   700.905226              0.0
# min      1.000000         1.000000    15.000000              1.0
# 25%     98.750000        25.000000   218.000000              1.0
# 50%    198.500000        25.000000   402.000000              1.0
# 75%    294.250000        25.000000   750.000000              1.0
# max    381.000000        29.000000  3585.000000              1.0
#
#           viewCount      likeCount  dislikeCount  favoriteCount  commentCount  \
# count  3.680000e+02     368.000000    368.000000          368.0    338.000000
# mean   1.762282e+05    4337.567935    416.070652            0.0   1103.437870
# std    7.072003e+05   19220.164569   2623.963882            0.0   4556.750099
# min    0.000000e+00       0.000000      0.000000            0.0      0.000000
# 25%    2.245250e+03      54.750000      7.000000            0.0     24.000000
# 50%    1.459850e+04     241.000000     49.500000            0.0    137.500000
# 75%    7.982375e+04    1567.500000    156.500000            0.0    618.750000
# max    7.435424e+06  267054.000000  45290.000000            0.0  68194.000000
#
#        dislikeCount_no_na
# count          368.000000
# mean           416.070652
# std           2623.963882
# min              0.000000
# 25%              7.000000
# 50%             49.500000
# 75%            156.500000
# max          45290.000000

# %%
videos_sent['category'].value_counts()
# Out:
# News & Politics                      220
# Other                                 68
# Education, Science and Technology     65
# Nonprofits & Activism                 15
# Name: category, dtype: int64

# %%
videos_sent['category'].value_counts(normalize=True)
# Out:
# News & Politics                      0.597826
# Other                                0.184783
# Education, Science and Technology    0.176630
# Nonprofits & Activism                0.040761
# Name: category, dtype: float64

# %% [markdown]
# ## We're done!
#
# ## But just because I am curious...
#
# Let's see quickly how engagement varies...

# %%
videos_sent.groupby('neutral')[['likeCount', 'dislikeCount', 'viewCount']].describe().transpose()
# Out:
# neutral                       -1             0             1
# likeCount    count  9.100000e+01  2.630000e+02  1.400000e+01
#              mean   2.119143e+03  5.001376e+03  6.287214e+03
#              std    5.234845e+03  2.217068e+04  1.689047e+04
#              min    0.000000e+00  0.000000e+00  0.000000e+00
#              25%    1.365000e+02  4.100000e+01  3.100000e+01
#              50%    5.230000e+02  1.870000e+02  1.060000e+03
#              75%    1.744500e+03  1.228000e+03  3.483500e+03
#              max    4.007000e+04  2.670540e+05  6.450300e+04
# dislikeCount count  9.100000e+01  2.630000e+02  1.400000e+01
#              mean   2.218901e+02  4.856692e+02  3.707857e+02
#              std    4.235332e+02  3.084362e+03  1.019189e+03
#              min    0.000000e+00  0.000000e+00  0.000000e+00
#              25%    2.500000e+01  4.000000e+00  1.250000e+01
#              50%    7.200000e+01  4.000000e+01  5.500000e+01
#              75%    1.955000e+02  1.435000e+02  1.602500e+02
#              max    2.997000e+03  4.529000e+04  3.885000e+03
# viewCount    count  9.100000e+01  2.630000e+02  1.400000e+01
#              mean   1.415856e+05  1.802056e+05  3.266875e+05
#              std    5.504898e+05  7.457688e+05  8.826503e+05
#              min    2.200000e+01  0.000000e+00  2.000000e+00
#              25%    5.981000e+03  1.582000e+03  1.740000e+03
#              50%    3.105600e+04  8.506000e+03  3.394250e+04
#              75%    9.768200e+04  6.687950e+04  7.741250e+04
#              max    5.153641e+06  7.435424e+06  3.341806e+06

# %% [markdown]
# Pandas is using scientific notation because of other columns being too large. So let's change this.

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
videos_sent.groupby('neutral')[['likeCount', 'dislikeCount', 'viewCount']].describe().transpose()
# Out:
# neutral                     -1           0           1
# likeCount    count      91.000     263.000      14.000
#              mean     2119.143    5001.376    6287.214
#              std      5234.845   22170.676   16890.473
#              min         0.000       0.000       0.000
#              25%       136.500      41.000      31.000
#              50%       523.000     187.000    1060.000
#              75%      1744.500    1228.000    3483.500
#              max     40070.000  267054.000   64503.000
# dislikeCount count      91.000     263.000      14.000
#              mean      221.890     485.669     370.786
#              std       423.533    3084.362    1019.189
#              min         0.000       0.000       0.000
#              25%        25.000       4.000      12.500
#              50%        72.000      40.000      55.000
#              75%       195.500     143.500     160.250
#              max      2997.000   45290.000    3885.000
# viewCount    count      91.000     263.000      14.000
#              mean   141585.560  180205.570  326687.500
#              std    550489.832  745768.750  882650.307
#              min        22.000       0.000       2.000
#              25%      5981.000    1582.000    1740.000
#              50%     31056.000    8506.000   33942.500
#              75%     97682.000   66879.500   77412.500
#              max   5153641.000 7435424.000 3341806.000

# %%
videos_sent.groupby('category')[['likeCount', 'dislikeCount', 'viewCount']].mean().transpose()
# Out:
# category      Education, Science and Technology  News & Politics  \
# likeCount                             12317.154         2257.755
# dislikeCount                           1028.554          329.214
# viewCount                            447470.969       113570.941
#
# category      Nonprofits & Activism      Other
# likeCount                  2305.200   3887.147
# dislikeCount                 92.867    182.912
# viewCount                120068.533 132054.824

# %%
videos_sent.groupby('category')[['likeCount', 'dislikeCount', 'viewCount']].std().transpose()
# Out:
# category      Education, Science and Technology  News & Politics  \
# likeCount                             41581.233         7042.328
# dislikeCount                           5650.599         1392.316
# viewCount                           1379156.918       441305.367
#
# category      Nonprofits & Activism      Other
# likeCount                  5546.039  11237.791
# dislikeCount                150.259    637.465
# viewCount                202106.345 436535.035

# %% [markdown]
# To make it more readable, you can use transpose (columns become rows, and vice-versa)

# %%
videos_sent.to_pickle('videos_sent.pkl')
